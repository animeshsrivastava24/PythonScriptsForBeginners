# %% [markdown]
# In this assignment, I'll be using what I've learnt about numpy, pandas and matplotlib to analyze and visualize the Chinook database.
# The Chinook database contains information about the media in their store, their customers and employees, and their invoice.

# %%
#importing libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. Which city has the best customers?

# %% [markdown]
# ##### This is the city with the highest sum of invoice totals. It'll be an ideal place for a promotional music festival

# %%
#loading invoice data

invoice = pd.read_csv("Invoice.csv")
invoice.head()
# Out:
#    InvoiceId  CustomerId  InvoiceDate           BillingAddress BillingCity  \
# 0          1           2          NaN  Theodor-Heuss-Straße 34   Stuttgart
# 1          2           4          NaN         Ullevålsveien 14        Oslo
# 2          3           8          NaN          Grétrystraat 63    Brussels
# 3          4          14          NaN           8210 111 ST NW    Edmonton
# 4          5          23          NaN          69 Salem Street      Boston
#
#   BillingState BillingCountry BillingPostalCode  Total
# 0          NaN        Germany             70174   1.98
# 1          NaN         Norway              0171   3.96
# 2          NaN        Belgium              1000   5.94
# 3           AB         Canada           T6G 2C7   8.91
# 4           MA            USA              2113  13.86

# %%
# This returns the city name and sum total of the city with the highest sum of invoice totals.
 
best_city = invoice[['BillingCity', 'Total']].groupby('BillingCity').sum().sort_values(by = 'Total', ascending = False)

print(best_city.head(1))
# Out:
#              Total
# BillingCity
# Prague       90.24

# %%
# a bar chart showing total invoice from each city

plt.figure(figsize=(20,30))
plt.barh('BillingCity', 'Total', data=invoice)
plt.xlabel('Invoice Totals')
plt.ylabel('City')
plt.title('Invoice Total by City')
plt.show()

# %% [markdown]
# ##### From the bar plot, we see that Prague is the city with the best customers, hence the music festival should be held there.

# %% [markdown]
# ## 2. Which countries have the most Invoices?

# %%
# This return a table of BillingCountry and Invoices ordered by the number of invoices for each country.
# The country with the most invoices will appear first. 

best_country = invoice['BillingCountry'].value_counts()
print(best_country)
# Out:
# USA               91
# Canada            56
# France            35
# Brazil            35
# Germany           28
# United Kingdom    21
# Czech Republic    14
# Portugal          14
# India             13
# Italy              7
# Denmark            7
# Finland            7
# Argentina          7
# Belgium            7
# Poland             7
# Australia          7
# Austria            7
# Netherlands        7
# Spain              7
# Ireland            7
# Chile              7
# Sweden             7
# Hungary            7
# Norway             7
# Name: BillingCountry, dtype: int64

# %%
#### The top 5 countries with the most invoices are USA, Canada, France, Brazil and Germany.

# %% [markdown]
# ## 3. Who is the best customer?
#
# ##### The best customer is the customer who has spent the most money.

# %%
#loading customer data

customers = pd.read_csv('Customer.csv')
customers.head()
# Out:
#    CustomerId  FirstName     LastName  \
# 0           1       Luís    Gonçalves
# 1           2     Leonie       Köhler
# 2           3   François     Tremblay
# 3           4      Bjørn       Hansen
# 4           5  František  Wichterlová
#
#                                             Company  \
# 0  Embraer - Empresa Brasileira de Aeronáutica S.A.
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                  JetBrains s.r.o.
#
#                            Address                 City State         Country  \
# 0  Av. Brigadeiro Faria Lima, 2170  São José dos Campos    SP          Brazil
# 1          Theodor-Heuss-Straße 34            Stuttgart   NaN         Germany
# 2                1498 rue Bélanger             Montréal    QC          Canada
# 3                 Ullevålsveien 14                 Oslo   NaN          Norway
# 4                    Klanova 9/506               Prague   NaN  Czech Republic
#
#   PostalCode               Phone                 Fax  \
# 0  12227-000  +55 (12) 3923-5555  +55 (12) 3923-5566
# 1      70174    +49 0711 2842222                 NaN
# 2    H2G 1A7   +1 (514) 721-4711                 NaN
# 3       0171     +47 22 44 22 22                 NaN
# 4      14700    +420 2 4172 5555    +420 2 4172 5555
#
#                       Email  SupportRepId
# 0      luisg@embraer.com.br             3
# 1     leonekohler@surfeu.de             5
# 2       ftremblay@gmail.com             3
# 3     bjorn.hansen@yahoo.no             4
# 4  frantisekw@jetbrains.com             4

# %%
# The customer who has spent the most money

best_customer = invoice[['CustomerId', 'Total']].groupby('CustomerId')['Total'].sum().sort_values(ascending = False).head(1)
print(best_customer)
# Out:
# CustomerId
# 6    49.62
# Name: Total, dtype: float64

# %%
#Details of customer with ID no 6

customers[customers['CustomerId'] == 6]
# Out:
#    CustomerId FirstName LastName Company        Address    City State  \
# 5           6    Helena     Holý     NaN  Rilská 3174/6  Prague   NaN
#
#           Country PostalCode             Phone  Fax            Email  \
# 5  Czech Republic      14300  +420 2 4177 0449  NaN  hholy@gmail.com
#
#    SupportRepId
# 5             5

# %% [markdown]
# #### The best customer is from Prague, her name is Helena Holy

# %% [markdown]
# ## 4. Details of customers who listen to rock music

# %%
#loading the Genre data

genre = pd.read_csv('Genre.csv')
genre.head()
# Out:
#    GenreId                Name
# 0        1                Rock
# 1        2                Jazz
# 2        3               Metal
# 3        4  Alternative & Punk
# 4        5       Rock And Roll

# %%
#loading Track data

tracks = pd.read_csv('Track.csv')
tracks.head()
# Out:
#    TrackId                                     Name  AlbumId  MediaTypeId  \
# 0        1  For Those About To Rock (We Salute You)        1            1
# 1        2                        Balls to the Wall        2            2
# 2        3                          Fast As a Shark        3            2
# 3        4                        Restless and Wild        3            2
# 4        5                     Princess of the Dawn        3            2
#
#    GenreId                                           Composer  Milliseconds  \
# 0        1          Angus Young, Malcolm Young, Brian Johnson        343719
# 1        1                                                NaN        342562
# 2        1  F. Baltes, S. Kaufman, U. Dirkscneider & W. Ho...        230619
# 3        1  F. Baltes, R.A. Smith-Diesel, S. Kaufman, U. D...        252051
# 4        1                         Deaffy & R.A. Smith-Diesel        375418
#
#       Bytes  UnitPrice
# 0  11170334       0.99
# 1   5510424       0.99
# 2   3990994       0.99
# 3   4331779       0.99
# 4   6290521       0.99

# %%
#loading Invoiceline data

invoice_line = pd.read_csv('InvoiceLine.csv')
invoice_line.head()
# Out:
#    InvoiceLineId  InvoiceId  TrackId  UnitPrice  Quantity
# 0              1          1        2       0.99         1
# 1              2          1        4       0.99         1
# 2              3          2        6       0.99         1
# 3              4          2        8       0.99         1
# 4              5          2       10       0.99         1

# %%
# merging genre and track dataframes 

genre_tracks = pd.merge(tracks[['TrackId', 'GenreId']], genre, on = 'GenreId', how = 'right')
genre_tracks.head()
# Out:
#    TrackId  GenreId  Name
# 0        1        1  Rock
# 1        2        1  Rock
# 2        3        1  Rock
# 3        4        1  Rock
# 4        5        1  Rock

# %% [markdown]
# #####  We can now use data on customer ID to get the kind of track they purchased.

# %%
# merging invoice line data and invoive data to get each customer ID with invoice details

purchases = pd.merge(invoice_line[['InvoiceId', 'TrackId']], invoice[['InvoiceId', 'CustomerId']], on = 'InvoiceId', how = 'left')
purchases.head()
# Out:
#    InvoiceId  TrackId  CustomerId
# 0          1        2           2
# 1          1        4           2
# 2          2        6           4
# 3          2        8           4
# 4          2       10           4

# %%
# merging purchases with genre_tracks to get the name of track corresponding to each customer's purchase 

genre_category = pd.merge(purchases, genre_tracks, on = 'TrackId', how = 'left')
genre_category.head()
# Out:
#    InvoiceId  TrackId  CustomerId  GenreId  Name
# 0          1        2           2        1  Rock
# 1          1        4           2        1  Rock
# 2          2        6           4        1  Rock
# 3          2        8           4        1  Rock
# 4          2       10           4        1  Rock

# %%
# getting customers details, we can then use their ID to get the genre of tracks each customer purchased.

customer_details = customers[['CustomerId', 'Email', 'FirstName', 'LastName', 'City', 'Country']]
customer_details.head()
# Out:
#    CustomerId                     Email  FirstName     LastName  \
# 0           1      luisg@embraer.com.br       Luís    Gonçalves
# 1           2     leonekohler@surfeu.de     Leonie       Köhler
# 2           3       ftremblay@gmail.com   François     Tremblay
# 3           4     bjorn.hansen@yahoo.no      Bjørn       Hansen
# 4           5  frantisekw@jetbrains.com  František  Wichterlová
#
#                   City         Country
# 0  São José dos Campos          Brazil
# 1            Stuttgart         Germany
# 2             Montréal          Canada
# 3                 Oslo          Norway
# 4               Prague  Czech Republic

# %%
# category of genre purchased by eash customer

customer_genre = pd.merge(genre_category[['CustomerId', 'Name']], customer_details, on = 'CustomerId', how = 'left')
customer_genre.head()
# Out:
#    CustomerId  Name                  Email FirstName LastName       City  \
# 0           2  Rock  leonekohler@surfeu.de    Leonie   Köhler  Stuttgart
# 1           2  Rock  leonekohler@surfeu.de    Leonie   Köhler  Stuttgart
# 2           4  Rock  bjorn.hansen@yahoo.no     Bjørn   Hansen       Oslo
# 3           4  Rock  bjorn.hansen@yahoo.no     Bjørn   Hansen       Oslo
# 4           4  Rock  bjorn.hansen@yahoo.no     Bjørn   Hansen       Oslo
#
#    Country
# 0  Germany
# 1  Germany
# 2   Norway
# 3   Norway
# 4   Norway

# %%
# This returns contact details of all Rock Music listeners in alphabetical order(Email)
# This is done by selecting rows with logic 

customer_genre[customer_genre['Name'] == 'Rock'].sort_values(by = 'Email', ascending = True)
# Out:
#       CustomerId  Name                   Email FirstName  LastName      City  \
# 266           32  Rock  aaronmitchell@yahoo.ca     Aaron  Mitchell  Winnipeg
# 267           32  Rock  aaronmitchell@yahoo.ca     Aaron  Mitchell  Winnipeg
# 1569          32  Rock  aaronmitchell@yahoo.ca     Aaron  Mitchell  Winnipeg
# 333           32  Rock  aaronmitchell@yahoo.ca     Aaron  Mitchell  Winnipeg
# 1564          32  Rock  aaronmitchell@yahoo.ca     Aaron  Mitchell  Winnipeg
# ...          ...   ...                     ...       ...       ...       ...
# 1162          42  Rock   wyatt.girard@yahoo.fr     Wyatt    Girard  Bordeaux
# 1161          42  Rock   wyatt.girard@yahoo.fr     Wyatt    Girard  Bordeaux
# 160           42  Rock   wyatt.girard@yahoo.fr     Wyatt    Girard  Bordeaux
# 162           42  Rock   wyatt.girard@yahoo.fr     Wyatt    Girard  Bordeaux
# 1166          42  Rock   wyatt.girard@yahoo.fr     Wyatt    Girard  Bordeaux
#
#      Country
# 266   Canada
# 267   Canada
# 1569  Canada
# 333   Canada
# 1564  Canada
# ...      ...
# 1162  France
# 1161  France
# 160   France
# 162   France
# 1166  France
#
# [835 rows x 7 columns]

# %% [markdown]
# ## 5. Most popular music genre for each country
#
# #### The most popular genre is the genre with the highest amount of purchases.

# %%
# merging invoice lines data with invoice data so we can match invoice line items to customers

customer_purchase = pd.merge(invoice_line, invoice[['InvoiceId', 'CustomerId', 'BillingCountry']], on = 'InvoiceId', how = 'left')
customer_purchase.head()
# Out:
#    InvoiceLineId  InvoiceId  TrackId  UnitPrice  Quantity  CustomerId  \
# 0              1          1        2       0.99         1           2
# 1              2          1        4       0.99         1           2
# 2              3          2        6       0.99         1           4
# 3              4          2        8       0.99         1           4
# 4              5          2       10       0.99         1           4
#
#   BillingCountry
# 0        Germany
# 1        Germany
# 2         Norway
# 3         Norway
# 4         Norway

# %% [markdown]
# ##### The dataframe can now be completed by adding the genre for each track purchased.

# %%
# Adding genre of track purchased to customer_purchase data

customer_purchase = pd.merge(customer_purchase, genre_tracks, on = 'TrackId', how = 'left')
customer_purchase.head()
# Out:
#    InvoiceLineId  InvoiceId  TrackId  UnitPrice  Quantity  CustomerId  \
# 0              1          1        2       0.99         1           2
# 1              2          1        4       0.99         1           2
# 2              3          2        6       0.99         1           4
# 3              4          2        8       0.99         1           4
# 4              5          2       10       0.99         1           4
#
#   BillingCountry  GenreId  Name
# 0        Germany        1  Rock
# 1        Germany        1  Rock
# 2         Norway        1  Rock
# 3         Norway        1  Rock
# 4         Norway        1  Rock

# %%
# Calculating the amount of purchases made in each country based on genre of track purchased.

genre_totals = pd.DataFrame(customer_purchase.groupby(['BillingCountry', 'Name'], as_index=False)['UnitPrice'].sum())
genre_totals.head()
# Out:
#   BillingCountry                Name  UnitPrice
# 0      Argentina  Alternative & Punk       8.91
# 1      Argentina      Easy Listening       1.98
# 2      Argentina                Jazz       1.98
# 3      Argentina               Latin       7.92
# 4      Argentina               Metal       6.93

# %% [markdown]
# ##### We can now find the highest revenue from a single genre for each country.

# %%
#  This returns the genre with the highest amount of purchases for each country.

max_purchase = pd.DataFrame(genre_totals.groupby('BillingCountry')['UnitPrice'].max())
max_purchase.head()
# Out:
#                 UnitPrice
# BillingCountry
# Argentina            8.91
# Australia           21.78
# Austria             14.85
# Belgium             20.79
# Brazil              80.19

# %%
# Most popular genre by country

pd.merge(max_purchase, genre_totals, on = ['UnitPrice', 'BillingCountry'], how = 'left')
# Out:
#     UnitPrice  BillingCountry                Name
# 0        8.91       Argentina  Alternative & Punk
# 1        8.91       Argentina                Rock
# 2       21.78       Australia                Rock
# 3       14.85         Austria                Rock
# 4       20.79         Belgium                Rock
# 5       80.19          Brazil                Rock
# 6      105.93          Canada                Rock
# 7        8.91           Chile                Rock
# 8       24.75  Czech Republic                Rock
# 9       20.79         Denmark                Rock
# 10      17.82         Finland                Rock
# 11      64.35          France                Rock
# 12      61.38         Germany                Rock
# 13      10.89         Hungary                Rock
# 14      24.75           India                Rock
# 15      13.93         Ireland            TV Shows
# 16      17.82           Italy                Rock
# 17      17.82     Netherlands                Rock
# 18      16.83          Norway                Rock
# 19      21.78          Poland                Rock
# 20      30.69        Portugal                Rock
# 21      21.78           Spain                Rock
# 22      11.88          Sweden               Latin
# 23     155.43             USA                Rock
# 24      36.63  United Kingdom                Rock
